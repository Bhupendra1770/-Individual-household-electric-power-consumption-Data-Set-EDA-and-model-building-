# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Attribute Information:
#
# 1.date: Date in format dd/mm/yyyy
#
# 2.time: time in format hh:mm:ss
#
# 3.global_active_power: household global minute-averaged active power (in kilowatt)
#
# 4.global_reactive_power: household global minute-averaged reactive power (in kilowatt)
#
# 5.voltage: minute-averaged voltage (in volt)
#
# 6.global_intensity: household global minute-averaged current intensity (in ampere)
#
# 7.sub_metering_1: energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a dishwasher, an oven and a microwave (hot plates are not electric but gas powered).
#
# 8.sub_metering_2: energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
#
# 9.sub_metering_3: energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.

# %% [markdown]
# Sub Datasets
# 1. Power Consumption.
# 2. Sub metering.
# 3. Global Reactive, Global Active and Global Intensity.

# %%
data=pd.read_csv('household_power_consumption.txt',sep=";", 
                 low_memory=False, na_values=['nan','?'])

# %%
data.head()
# Out:
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00                4.216                  0.418   234.84
# 1  16/12/2006  17:25:00                5.360                  0.436   233.63
# 2  16/12/2006  17:26:00                5.374                  0.498   233.29
# 3  16/12/2006  17:27:00                5.388                  0.502   233.74
# 4  16/12/2006  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %%
data.shape
# Out:
# (2075259, 9)

# %% [markdown]
# we have take sample of 50000 points

# %%
df=data.sample(50000).reset_index().drop('index',axis=1)

# %%
df.shape
# Out:
# (50000, 9)

# %%
df.head()
# Out:
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0    2/5/2010  07:32:00                1.452                  0.192   238.18
# 1   1/12/2009  00:53:00                0.480                  0.254   243.58
# 2   5/10/2008  01:03:00                1.302                  0.000   239.82
# 3   29/7/2007  21:00:00                0.102                  0.000   235.75
# 4  23/11/2010  07:42:00                2.150                  0.064   233.81
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0               6.0             0.0             2.0            18.0
# 1               2.2             0.0             2.0             1.0
# 2               5.4             0.0             0.0            18.0
# 3               0.4             0.0             0.0             0.0
# 4               9.2             0.0             0.0            17.0

# %%
df['Date']=pd.to_datetime(df['Date'])
# Out:
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '31/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '31/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '31/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '31/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '31/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '31/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '31/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/10/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '24/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '29/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '17/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '19/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/12/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '20/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '15/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '26/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '18/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '14/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '30/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '22/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '25/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/10/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '21/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '16/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '23/10/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '13/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '28/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '31/12/2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3023999556.py:1: UserWarning: Parsing '27/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])

# %%
df.drop('Time',axis=1,inplace=True)

# %%
df.head()
# Out:
#         Date  Global_active_power  Global_reactive_power  Voltage  \
# 0 2010-02-05                1.452                  0.192   238.18
# 1 2009-01-12                0.480                  0.254   243.58
# 2 2008-05-10                1.302                  0.000   239.82
# 3 2007-07-29                0.102                  0.000   235.75
# 4 2010-11-23                2.150                  0.064   233.81
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0               6.0             0.0             2.0            18.0
# 1               2.2             0.0             2.0             1.0
# 2               5.4             0.0             0.0            18.0
# 3               0.4             0.0             0.0             0.0
# 4               9.2             0.0             0.0            17.0

# %%
#grouping data on the basis of dates
df = df.groupby('Date').sum()

# %%
df.reset_index(inplace=True)

# %%
df['year']=df['Date'].dt.year
df['month']=df['Date'].dt.month

# %% [markdown]
# From 2006-12-16 to 2006-12-31 > 16 Days
#
# From 2007-01-01 to 2007-12-31 > 365 Days
#
# From 2008-01-01 to 2008-12-31 > 366 Days
#
# From 2009-01-01 to 2009-12-31 > 365 Days
#
# From 2010-01-01 to 2010-11-26 > 330 Days

# %%
# we are removing 2006 year because it may create problem while analysis
df = df[df['Date']>'2006-12-31']

# %%
df.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               56.764                  2.808   5770.23
# 17 2007-01-02               41.624                  2.584   7931.20
# 18 2007-01-03               14.550                  4.084  11549.96
# 19 2007-01-04               43.932                  3.094   5522.51
# 20 2007-01-05               52.910                  4.580  11495.73
#
#     Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  year  \
# 16             234.6             0.0             4.0            70.0  2007
# 17             174.8            37.0             6.0           334.0  2007
# 18              61.0             0.0            11.0            17.0  2007
# 19             185.2            73.0            88.0           300.0  2007
# 20             230.4            38.0            14.0           344.0  2007
#
#     month
# 16      1
# 17      1
# 18      1
# 19      1
# 20      1

# %%
df.shape
# Out:
# (1426, 10)

# %% [markdown]
# checking duplicated values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#dropping duplicate value
df = df.drop_duplicates()
df.shape
# Out:
# (1426, 10)

# %% [markdown]
# cheacking for null values

# %%
df.isnull().sum()
# Out:
# Date                     0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# year                     0
# month                    0
# dtype: int64

# %% [markdown]
# Global active power is the real power consumption i.e. the power consumed by electrical appliances other than the sub metered appliances.
#
# global_active_power*1000/60 - sub_metering_1 - sub_metering_2 - sub_metering_3) represents the active energy consumed every minute (in watt hour) in the household by electrical equipment not measured in sub-meterings 1, 2 and 3

# %%
#target variable power consumption
a = (df['Global_active_power']*1000/60) 
b = df['Sub_metering_1'] + df['Sub_metering_2'] + df['Sub_metering_3']
df['power_consumption'] = a - b
df.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               56.764                  2.808   5770.23
# 17 2007-01-02               41.624                  2.584   7931.20
# 18 2007-01-03               14.550                  4.084  11549.96
# 19 2007-01-04               43.932                  3.094   5522.51
# 20 2007-01-05               52.910                  4.580  11495.73
#
#     Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  year  \
# 16             234.6             0.0             4.0            70.0  2007
# 17             174.8            37.0             6.0           334.0  2007
# 18              61.0             0.0            11.0            17.0  2007
# 19             185.2            73.0            88.0           300.0  2007
# 20             230.4            38.0            14.0           344.0  2007
#
#     month  power_consumption
# 16      1         872.066667
# 17      1         316.733333
# 18      1         214.500000
# 19      1         271.200000
# 20      1         485.833333

# %%
#copy of data
df_copy = df.copy()

# %%
df['Sub_metering']=df['Sub_metering_1']+df['Sub_metering_2']+df['Sub_metering_3']

# %%
df = df.drop(['Sub_metering_1','Sub_metering_2','Sub_metering_3'],axis=1)

# %%
df.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               56.764                  2.808   5770.23
# 17 2007-01-02               41.624                  2.584   7931.20
# 18 2007-01-03               14.550                  4.084  11549.96
# 19 2007-01-04               43.932                  3.094   5522.51
# 20 2007-01-05               52.910                  4.580  11495.73
#
#     Global_intensity  year  month  power_consumption  Sub_metering
# 16             234.6  2007      1         872.066667          74.0
# 17             174.8  2007      1         316.733333         377.0
# 18              61.0  2007      1         214.500000          28.0
# 19             185.2  2007      1         271.200000         461.0
# 20             230.4  2007      1         485.833333         396.0

# %%
df.corr()
# Out:
#                        Global_active_power  Global_reactive_power   Voltage  \
# Global_active_power               1.000000               0.270195  0.427187
# Global_reactive_power             0.270195               1.000000  0.513621
# Voltage                           0.427187               0.513621  1.000000
# Global_intensity                  0.999198               0.291047  0.433741
# year                             -0.049438               0.135845  0.000081
# month                            -0.015230               0.020324 -0.006289
# power_consumption                 0.881514               0.154127  0.396688
# Sub_metering                      0.870606               0.322816  0.350950
#
#                        Global_intensity      year     month  \
# Global_active_power            0.999198 -0.049438 -0.015230
# Global_reactive_power          0.291047  0.135845  0.020324
# Voltage                        0.433741  0.000081 -0.006289
# Global_intensity               1.000000 -0.059300 -0.017026
# year                          -0.059300  1.000000 -0.034370
# month                         -0.017026 -0.034370  1.000000
# power_consumption              0.878833 -0.137919 -0.016763
# Sub_metering                   0.871966  0.055258 -0.009782
#
#                        power_consumption  Sub_metering
# Global_active_power             0.881514      0.870606
# Global_reactive_power           0.154127      0.322816
# Voltage                         0.396688      0.350950
# Global_intensity                0.878833      0.871966
# year                           -0.137919      0.055258
# month                          -0.016763     -0.009782
# power_consumption               1.000000      0.535159
# Sub_metering                    0.535159      1.000000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df['Global_intensity'],df['Global_active_power'])

# %%
df.describe().T
# Out:
#                         count         mean          std     min        25%  \
# Global_active_power    1426.0    36.921447    16.568255     0.0    25.9360
# Global_reactive_power  1426.0     4.238525     1.573598     0.0     3.1805
# Voltage                1426.0  8254.075133  1650.569452     0.0  7290.7200
# Global_intensity       1426.0   156.569705    68.940843     0.0   111.0500
# year                   1426.0  2008.462833     1.106450  2007.0  2007.0000
# month                  1426.0     6.437588     3.410299     1.0     3.0000
# power_consumption      1426.0   315.110612   160.821639     0.0   204.4750
# Sub_metering           1426.0   300.246844   154.341956     0.0   192.0000
#
#                                50%          75%           max
# Global_active_power      35.808000    46.178000     99.748000
# Global_reactive_power     4.047000     5.084000     13.128000
# Voltage                8276.165000  9316.275000  12822.770000
# Global_intensity        151.500000   193.600000    421.800000
# year                   2008.000000  2009.000000   2010.000000
# month                     6.000000     9.000000     12.000000
# power_consumption       290.616667   394.791667   1049.366667
# Sub_metering            288.000000   390.750000    894.000000

# %%
df.columns
# Out:
# Index(['Date', 'Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'year', 'month', 'power_consumption',
#        'Sub_metering'],
#       dtype='object')

# %%
#creating a list of column for our graphical analysis
columns=list(df.columns)
df_graph_col=columns[1:9]
df_graph_col
# Out:
# ['Global_active_power',
#  'Global_reactive_power',
#  'Voltage',
#  'Global_intensity',
#  'year',
#  'month',
#  'power_consumption',
#  'Sub_metering']

# %% [markdown]
# Grouping our data on the basis of year for calculating total power consumption in every year

# %%
df_year=pd.DataFrame(df.groupby('year')['power_consumption'].sum())

# %%
df_year
# Out:
#       power_consumption
# year
# 2007      122897.500000
# 2008      123535.200000
# 2009      109931.133333
# 2010       92983.900000

# %%
df_year.describe().T
# Out:
#                    count           mean           std      min         25%  \
# power_consumption    4.0  112336.933333  14344.040778  92983.9  105694.325
#
#                              50%         75%       max
# power_consumption  116414.316667  123056.925  123535.2

# %%
df_year.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# maximum power consume in year 2007

# %%
df.describe().T
# Out:
#                         count         mean          std     min        25%  \
# Global_active_power    1426.0    36.921447    16.568255     0.0    25.9360
# Global_reactive_power  1426.0     4.238525     1.573598     0.0     3.1805
# Voltage                1426.0  8254.075133  1650.569452     0.0  7290.7200
# Global_intensity       1426.0   156.569705    68.940843     0.0   111.0500
# year                   1426.0  2008.462833     1.106450  2007.0  2007.0000
# month                  1426.0     6.437588     3.410299     1.0     3.0000
# power_consumption      1426.0   315.110612   160.821639     0.0   204.4750
# Sub_metering           1426.0   300.246844   154.341956     0.0   192.0000
#
#                                50%          75%           max
# Global_active_power      35.808000    46.178000     99.748000
# Global_reactive_power     4.047000     5.084000     13.128000
# Voltage                8276.165000  9316.275000  12822.770000
# Global_intensity        151.500000   193.600000    421.800000
# year                   2008.000000  2009.000000   2010.000000
# month                     6.000000     9.000000     12.000000
# power_consumption       290.616667   394.791667   1049.366667
# Sub_metering            288.000000   390.750000    894.000000

# %% [markdown]
# we can see that maximum power consumption in a day is 675.04 w/h
#
# average consumption is 310.14 w/h
#
# minimum cosmption 0.0

# %% [markdown]
# # Grouping data on the basis of 'month' and 'year' so we can calculate total power consumption in each month of every year.

# %%
df_year_month=pd.DataFrame(df.groupby(['year','month'])['power_consumption'].sum())

# %%
df_year_month
# Out:
#             power_consumption
# year month
# 2007 1           13940.066667
#      2           10577.533333
#      3           11691.966667
#      4            8556.133333
#      5            9205.066667
#      6            7655.533333
#      7            6999.200000
#      8            7951.066667
#      9            8974.666667
#      10           9923.866667
#      11          13049.800000
#      12          14372.600000
# 2008 1           14695.266667
#      2           10800.533333
#      3           10611.300000
#      4            9158.133333
#      5            9063.566667
#      6            8195.566667
#      7            8369.866667
#      8            5099.600000
#      9            8561.700000
#      10          11941.433333
#      11          14228.133333
#      12          12810.100000
# 2009 1           12574.400000
#      2            9081.133333
#      3            9659.533333
#      4            9683.300000
#      5            8847.300000
#      6            6398.700000
#      7            6379.666667
#      8            6804.966667
#      9            8546.333333
#      10          10666.066667
#      11          10674.200000
#      12          10615.533333
# 2010 1           10176.666667
#      2            8725.233333
#      3            8924.266667
#      4            8012.166667
#      5            8693.100000
#      6            7307.100000
#      7            7145.233333
#      8            5727.400000
#      9            6262.100000
#      10          10230.966667
#      11           8884.000000
#      12           2895.666667

# %%
plt.figure(figsize=(25,25))
l = list(df.groupby('year').sum().index)
for i in range(len(l)):
    plt.subplot(4,6,i+1)
    df.groupby(df[df['year']==l[i]]['month'])['power_consumption'].sum().plot(kind='bar')

# %%
df_year_month.describe().T
# Out:
#                    count         mean          std          min          25%  \
# power_consumption   48.0  9361.411111  2495.903243  2895.666667  7996.891667
#
#                            50%           75%           max
# power_consumption  9019.116667  10628.166667  14695.266667

# %% [markdown]
# so power consumption in december month of year 2007 is maximum

# %%
df_anal = pd.DataFrame(df.groupby(['year','month']).sum()['power_consumption'])
df_anal.reset_index(inplace=True)
df_anal
# Out:
#     year  month  power_consumption
# 0   2007      1       13940.066667
# 1   2007      2       10577.533333
# 2   2007      3       11691.966667
# 3   2007      4        8556.133333
# 4   2007      5        9205.066667
# 5   2007      6        7655.533333
# 6   2007      7        6999.200000
# 7   2007      8        7951.066667
# 8   2007      9        8974.666667
# 9   2007     10        9923.866667
# 10  2007     11       13049.800000
# 11  2007     12       14372.600000
# 12  2008      1       14695.266667
# 13  2008      2       10800.533333
# 14  2008      3       10611.300000
# 15  2008      4        9158.133333
# 16  2008      5        9063.566667
# 17  2008      6        8195.566667
# 18  2008      7        8369.866667
# 19  2008      8        5099.600000
# 20  2008      9        8561.700000
# 21  2008     10       11941.433333
# 22  2008     11       14228.133333
# 23  2008     12       12810.100000
# 24  2009      1       12574.400000
# 25  2009      2        9081.133333
# 26  2009      3        9659.533333
# 27  2009      4        9683.300000
# 28  2009      5        8847.300000
# 29  2009      6        6398.700000
# 30  2009      7        6379.666667
# 31  2009      8        6804.966667
# 32  2009      9        8546.333333
# 33  2009     10       10666.066667
# 34  2009     11       10674.200000
# 35  2009     12       10615.533333
# 36  2010      1       10176.666667
# 37  2010      2        8725.233333
# 38  2010      3        8924.266667
# 39  2010      4        8012.166667
# 40  2010      5        8693.100000
# 41  2010      6        7307.100000
# 42  2010      7        7145.233333
# 43  2010      8        5727.400000
# 44  2010      9        6262.100000
# 45  2010     10       10230.966667
# 46  2010     11        8884.000000
# 47  2010     12        2895.666667

# %%
df_month_anal=pd.DataFrame(df_anal.groupby('year')['power_consumption'].max())

# %%
df_month_anal
# Out:
#       power_consumption
# year
# 2007       14372.600000
# 2008       14695.266667
# 2009       12574.400000
# 2010       10230.966667

# %%
df_year.reset_index(inplace=True)

# %% [markdown]
# so highest power consumption in month in each year

# %%
sns.barplot(x='year',y ='power_consumption',data=df_year)
# Out:
# <AxesSubplot:xlabel='year', ylabel='power_consumption'>

# %%
df_year.describe().T
# Out:
#                    count           mean           std      min         25%  \
# year                 4.0    2008.500000      1.290994   2007.0    2007.750
# power_consumption    4.0  112336.933333  14344.040778  92983.9  105694.325
#
#                              50%         75%       max
# year                 2008.500000    2009.250    2010.0
# power_consumption  116414.316667  123056.925  123535.2

# %% [markdown]
# So we can conclude that maximum of total power consume in year 2007 and in minimum in 2010

# %% [markdown]
# # plotting graph of our features

# %%
#plt.figure(figsize=(15,15))
#for i in range(len(df_graph_col)):
    #plt.subplot(4,4,i+1)
    #sns.distplot(df[df_graph_col[i]])

# %%
plt.figure(figsize=(15,15))
for i in range(df.shape[1]-1):
    plt.subplot(3,3,i+1)
    sns.kdeplot(df.iloc[:,i])

# %% [markdown]
# mostly features arer normally distributed

# %% [markdown]
# # Box plot for checking outliers

# %%
plt.figure(figsize=(10,10))
for i,col in enumerate(df_graph_col):
    plt.subplot(3,3,i+1)
    sns.boxplot(df[col])
# Out:
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# So we have many outliers so we have to treat them for better anlysis as well as for model building

# %%
# Function to detect outliers
def outlier_thresholds(dataframe, variable):
    quartile1 = dataframe[variable].quantile(0.25)
    quartile3 = dataframe[variable].quantile(0.75)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit


## function to remove outliers
def replace_with_thresholds(dataframe,columns):
    for col in columns:
        low_limit, up_limit = outlier_thresholds(dataframe, col)
        dataframe.loc[(dataframe[col] < low_limit), col] = low_limit
        dataframe.loc[(dataframe[col] > up_limit), col] = up_limit

# %% [markdown]
# we have create a function which check outliers and treat them with help of lower limit and upper limit

# %%
replace_with_thresholds(df,columns)

# %%
#again checkin for outliers 
plt.figure(figsize=(10,10))
for i,col in enumerate(df_graph_col):
    plt.subplot(3,3,i+1)
    sns.boxplot(df[col])
# Out:
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# so our outliers has been treated

# %%
plt.figure(figsize=(15,15))
for i in range(len(df_graph_col)):
    plt.subplot(3,3,i+1)
    sns.distplot(df[df_graph_col[i]])
# Out:
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_copy.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               56.764                  2.808   5770.23
# 17 2007-01-02               41.624                  2.584   7931.20
# 18 2007-01-03               14.550                  4.084  11549.96
# 19 2007-01-04               43.932                  3.094   5522.51
# 20 2007-01-05               52.910                  4.580  11495.73
#
#     Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  year  \
# 16             234.6             0.0             4.0            70.0  2007
# 17             174.8            37.0             6.0           334.0  2007
# 18              61.0             0.0            11.0            17.0  2007
# 19             185.2            73.0            88.0           300.0  2007
# 20             230.4            38.0            14.0           344.0  2007
#
#     month  power_consumption
# 16      1         872.066667
# 17      1         316.733333
# 18      1         214.500000
# 19      1         271.200000
# 20      1         485.833333

# %% [markdown]
# # Grouping data on the basis of year and month and find total sum of energy consumption in each sub_metering for each month of each year.

# %%
df_copy.groupby(['year','month'])['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum()
# Out:
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3451820653.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_copy.groupby(['year','month'])['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum()
#             Sub_metering_1  Sub_metering_2  Sub_metering_3
# year month
# 2007 1              1815.0          1524.0          7650.0
#      2               719.0          1526.0          5255.0
#      3              1524.0          2338.0          7169.0
#      4               947.0          1611.0          4715.0
#      5              1606.0          1754.0          5068.0
#      6              1254.0          1676.0          4526.0
#      7              1160.0          1712.0          4775.0
#      8              1029.0          1509.0          5785.0
#      9              1175.0          1810.0          5990.0
#      10              920.0          1859.0          5879.0
#      11             1151.0          1366.0          7152.0
#      12             1293.0          2095.0          8394.0
# 2008 1              1277.0          1155.0          6856.0
#      2               660.0          1053.0          5632.0
#      3              1845.0          1550.0          6235.0
#      4               881.0          1522.0          5947.0
#      5              1276.0          2128.0          7317.0
#      6              1544.0          1692.0          6445.0
#      7               877.0           813.0          5438.0
#      8               533.0          1210.0          3572.0
#      9              1423.0           951.0          7043.0
#      10             1327.0          1312.0          6329.0
#      11             1166.0          1160.0          7795.0
#      12             1482.0          1070.0          6951.0
# 2009 1              1376.0          1449.0          7495.0
#      2               678.0          1144.0          5986.0
#      3              1483.0          1055.0          6916.0
#      4               934.0          1702.0          6626.0
#      5              1168.0           974.0          7534.0
#      6               645.0           603.0          6009.0
#      7               541.0          1142.0          4868.0
#      8              1382.0           878.0          5769.0
#      9               965.0          1046.0          7340.0
#      10             1270.0          1467.0          7828.0
#      11             1816.0          1808.0          7770.0
#      12             1433.0           896.0          8571.0
# 2010 1              1246.0          1010.0          9549.0
#      2               914.0          1156.0          7737.0
#      3              1223.0          1614.0          7840.0
#      4              1085.0          1027.0          8070.0
#      5              1307.0           966.0          7828.0
#      6              1143.0          1130.0          7263.0
#      7               631.0           789.0          5087.0
#      8               603.0           895.0          5752.0
#      9               752.0           712.0          5626.0
#      10              634.0          1296.0          7491.0
#      11             1260.0           832.0          6315.0
#      12              222.0           389.0          2993.0

# %% [markdown]
# # Grouping data on the basis of year and month and find maximum energy consumption in each sub_metering for each month of each year.

# %%
df_copy.groupby(['year','month'])['Sub_metering_1','Sub_metering_2','Sub_metering_3'].max()
# Out:
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\3321635395.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_copy.groupby(['year','month'])['Sub_metering_1','Sub_metering_2','Sub_metering_3'].max()
#             Sub_metering_1  Sub_metering_2  Sub_metering_3
# year month
# 2007 1               375.0           227.0           494.0
#      2               150.0           218.0           422.0
#      3               186.0           317.0           472.0
#      4               174.0           386.0           352.0
#      5               177.0           340.0           319.0
#      6               165.0           251.0           323.0
#      7               112.0           276.0           370.0
#      8               201.0           230.0           579.0
#      9               214.0           269.0           371.0
#      10              133.0           230.0           370.0
#      11              163.0           201.0           462.0
#      12              179.0           290.0           476.0
# 2008 1               208.0           154.0           403.0
#      2               192.0           190.0           453.0
#      3               230.0           149.0           380.0
#      4               125.0           265.0           459.0
#      5               158.0           400.0           403.0
#      6               255.0           351.0           357.0
#      7               116.0            88.0           306.0
#      8               111.0           324.0           363.0
#      9               218.0           235.0           423.0
#      10              241.0           302.0           367.0
#      11              195.0           330.0           472.0
#      12              253.0           181.0           469.0
# 2009 1               389.0           258.0           440.0
#      2                85.0           333.0           532.0
#      3               228.0           200.0           436.0
#      4               119.0           299.0           458.0
#      5               115.0           215.0           393.0
#      6               134.0            85.0           394.0
#      7                93.0           172.0           387.0
#      8               233.0           110.0           394.0
#      9               117.0           268.0           508.0
#      10              178.0           275.0           490.0
#      11              260.0           276.0           534.0
#      12              199.0           118.0           555.0
# 2010 1               163.0           209.0           616.0
#      2               162.0           232.0           451.0
#      3               180.0           376.0           510.0
#      4               185.0           166.0           508.0
#      5               366.0           166.0           565.0
#      6               254.0           134.0           481.0
#      7               138.0           129.0           356.0
#      8               121.0           172.0           494.0
#      9               115.0           122.0           543.0
#      10              135.0           321.0           486.0
#      11              211.0           142.0           382.0
#      12              126.0           123.0           444.0

# %%
df_copy.groupby('year')['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum().plot(kind='bar')
# Out:
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\2058990090.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_copy.groupby('year')['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum().plot(kind='bar')
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# In each catagory of sub_metering we plot a graph and as we see that sub_metering_3 consume more energy than other two sub_metering
# and this is on the basis of total power consumption in each year.

# %%
df_copy.groupby('month')['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum().plot(kind='bar')
# Out:
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_3556\2552645704.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_copy.groupby('month')['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum().plot(kind='bar')
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# In each catagory of sub_metering we plot a graph and as we see that sub_metering_3 consume more energy than other two sub_metering and this is on the basis of total power consumption in each month of each year.

# %% [markdown]
# # Now we are good to go for model building

# %% [markdown]
# So we will create a regression model which can predict that how much power a house consume in a day on
# basis of some features.

# %%
plt.figure(figsize=(15,15))
for i in range(len(df_graph_col)):
    plt.subplot(3,3,i+1)
    sns.distplot(df[df_graph_col[i]])
# Out:
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               56.764                  2.808   5770.23
# 17 2007-01-02               41.624                  2.584   7931.20
# 18 2007-01-03               14.550                  4.084  11549.96
# 19 2007-01-04               43.932                  3.094   5522.51
# 20 2007-01-05               52.910                  4.580  11495.73
#
#     Global_intensity  year  month  power_consumption  Sub_metering
# 16             234.6  2007      1         680.266667          74.0
# 17             174.8  2007      1         316.733333         377.0
# 18              61.0  2007      1         214.500000          28.0
# 19             185.2  2007      1         271.200000         461.0
# 20             230.4  2007      1         485.833333         396.0

# %% [markdown]
# # We are selecting our independent and dependent feature.

# %%
x = df.iloc[:,[1,2,3,8]]  #Independent_feature

# %%
y = df.iloc[:,7]  #Dependent_feature

# %%
x.head(2)
# Out:
#     Global_active_power  Global_reactive_power  Voltage  Sub_metering
# 16               56.764                  2.808  5770.23          74.0
# 17               41.624                  2.584  7931.20         377.0

# %%
y.head(2)
# Out:
# 16    680.266667
# 17    316.733333
# Name: power_consumption, dtype: float64

# %%
sns.pairplot(x)

# %%
sns.regplot(x=df['Sub_metering'],y=df["power_consumption"],data=df)
# Out:
# <AxesSubplot:xlabel='Sub_metering', ylabel='power_consumption'>

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# we are spliting our data into train data and test data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=7,test_size=0.33)

# %% [markdown]
# standardize the datasets

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %% [markdown]
# # We are saving our preprocessing model in physcial file so we do not need to preprocess our data again and again before giving to model.

# %%
preprocess_model = [x_train,y_train,x_test,y_test]

# %%
import pickle

# %%
pickle.dump(preprocess_model, open('preprocess_model.pkl','wb'))

# %%
#load our model from pickle file
preprocess_model = pickle.load(open('preprocess_model.pkl','rb'))

# %% [markdown]
# we have successfully stored our scaled data into pickel file so we can use it further in other file by just importing it.

# %% [markdown]
# # Now we are saving data in NoSQL database mongodb after preprocessing

# %%
database_df = pd.DataFrame([x_train.T[0],x_train.T[1],x_train.T[2],x_train.T[3],y_train]).T

# %%
database_df.columns=['Global_active_power','Global_reactive_power','Voltage','Sub_metering','power_consumption']

# %%
database_df.head(2)
# Out:
#    Global_active_power  Global_reactive_power   Voltage  Sub_metering  \
# 0             1.938686              -0.609465  0.384122      0.639627
# 1             0.520797               0.902691 -0.108038      0.694100
#
#    power_consumption
# 0         680.266667
# 1         343.000000

# %%
l=[]
for i ,row in database_df.iterrows():
    l.append(dict(row))

# %%
import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://bhupendra:Rajput77@cluster0.xlf2p.mongodb.net/?retryWrites=true&w=majority")

# %%
db=client['preprocess_data']
collections = db['Table1']
collections.insert_many(l)

# %% [markdown]
# we have successfully inserted our scaled data into mongodb database
